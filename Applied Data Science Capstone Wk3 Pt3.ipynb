# %% [markdown]
# # Question 3
# ### Explore and cluster Toronto neighborhood data

# %%
#recreate dataframe from parts 1 and 2
import pandas as pd
toronto_codes = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
toronto_codes = toronto_codes[toronto_codes['Borough'] != 'Not assigned'].reset_index(drop = True)
latlong = pd.read_csv('https://cocl.us/Geospatial_data')
latlong.sort_values(by = 'Postal Code', inplace = True)
toronto_codes.sort_values(by = 'Postal code', inplace = True)
toronto_codes.reset_index(drop = True, inplace = True)
toronto_codes[['Latitude','Longitude']] = latlong[['Latitude','Longitude']]

# %%
toronto_codes.head()
# Out:
#   Postal code      Borough                              Neighborhood  \
# 0         M1B  Scarborough                           Malvern / Rouge
# 1         M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2         M1E  Scarborough       Guildwood / Morningside / West Hill
# 3         M1G  Scarborough                                    Woburn
# 4         M1H  Scarborough                                 Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# ### Let's plot a map with all the postal codes labeled

# %%
#install folium
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.0-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
toronto_map = folium.Map(location = [43.6532,-79.3832], zoom_start = 11)

for lat, long, bor, neigh in zip(toronto_codes['Latitude'],toronto_codes['Longitude'],toronto_codes['Borough'],toronto_codes['Neighborhood']):
    label = '{}, in {}'.format(neigh, bor)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=4,
        popup=label,
        color='green',
        fill=True,
        fill_opacity=0.5,
        parse_html=False).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Make use of Foursquare

# %%
# The code was removed by Watson Studio for sharing.

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import numpy as np

# %% [markdown]
# ### I'm going to cluster neighborhoods based on the most common kind of restaurant

# %%
#modify the function from the lab to search for restaurants within ~half a mile of each neighborhood center
def getNearbyRestaurants(names, latitudes, longitudes, radius=800, LIMIT = 50):
    
    restaurant_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&query=restaurant'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
        
        # return only relevant information for each nearby venue
        for v in results:
            try:
                restaurant_list.append((name, v['name'], v['categories'][0]['name']))
            except:
                restaurant_list.append((name, v['name'], np.nan))

    nearby_restaurants = pd.DataFrame(restaurant_list)
    nearby_restaurants.columns = ['Neighborhood', 
                  'Restaurant', 
                  'Restaurant Category']
    
    return(nearby_restaurants)

# %%
toronto_restaurants = getNearbyRestaurants(names=toronto_codes['Neighborhood'],
                                   latitudes=toronto_codes['Latitude'],
                                   longitudes=toronto_codes['Longitude']
                                  )
# Out:
# Malvern / Rouge
# Rouge Hill / Port Union / Highland Creek
# Guildwood / Morningside / West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park / Ionview / East Birchmount Park
# Golden Mile / Clairlea / Oakridge
# Cliffside / Cliffcrest / Scarborough Village West
# Birch Cliff / Cliffside West
# Dorset Park / Wexford Heights / Scarborough Town Centre
# Wexford / Maryvale
# Agincourt
# Clarks Corners / Tam O'Shanter / Sullivan
# Milliken / Agincourt North / Steeles East / L'Amoreaux East
# Steeles West / L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview / Henry Farm / Oriole
# Bayview Village
# York Mills / Silver Hills
# Willowdale / Newtonbrook
# Willowdale
# York Mills West
# Willowdale
# Parkwoods
# Don Mills
# Don Mills
# Bathurst Manor / Wilson Heights / Downsview North
# Northwood Park / York University
# Downsview
# Downsview
# Downsview
# Downsview
# Victoria Village
# Parkview Hill / Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West / Riverdale
# India Bazaar / The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park / Summerhill East
# Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park
# Rosedale
# St. James Town / Cabbagetown
# Church and Wellesley
# Regent Park / Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond / Adelaide / King
# Harbourfront East / Union Station / Toronto Islands
# Toronto Dominion Centre / Design Exchange
# Commerce Court / Victoria Hotel
# Bedford Park / Lawrence Manor East
# Roselawn
# Forest Hill North & West
# The Annex / North Midtown / Yorkville
# University of Toronto / Harbord
# Kensington Market / Chinatown / Grange Park
# CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst Quay / South Niagara / Island airport
# Stn A PO Boxes
# First Canadian Place / Underground city
# Lawrence Manor / Lawrence Heights
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dufferin / Dovercourt Village
# Little Portugal / Trinity
# Brockton / Parkdale Village / Exhibition Place
# North Park / Maple Leaf Park / Upwood Park
# Del Ray / Mount Dennis / Keelsdale and Silverthorn
# Runnymede / The Junction North
# High Park / The Junction South
# Parkdale / Roncesvalles
# Runnymede / Swansea
# Queen's Park / Ontario Provincial Government
# Canada Post Gateway Processing Centre
# Business reply mail Processing CentrE
# New Toronto / Mimico South / Humber Bay Shores
# Alderwood / Long Branch
# The Kingsway / Montgomery Road / Old Mill North
# Old Mill South / King's Mill Park / Sunnylea / Humber Bay / Mimico NE / The Queensway East / Royal York South East / Kingsway Park South East
# Mimico NW / The Queensway West / South of Bloor / Kingsway Park South West / Royal York South West
# Islington Avenue
# West Deane Park / Princess Gardens / Martin Grove / Islington / Cloverdale
# Eringate / Bloordale Gardens / Old Burnhamthorpe / Markland Wood
# Humber Summit
# Humberlea / Emery
# Weston
# Westmount
# Kingsview Village / St. Phillips / Martin Grove Gardens / Richview Gardens
# South Steeles / Silverstone / Humbergate / Jamestown / Mount Olive / Beaumond Heights / Thistletown / Albion Gardens
# Northwest
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-3687ebd29ba4> in <module>
#       4                                   )
#       5 toronto_restaurants.head()
# ----> 6 print(toronot_restaurants.shape)
#
# NameError: name 'toronot_restaurants' is not defined

# %%
print(toronto_restaurants.shape)
toronto_restaurants.head()
# Out:
# (1078, 3)
#                                Neighborhood                        Restaurant  \
# 0  Rouge Hill / Port Union / Highland Creek                  Ted's Restaurant
# 1       Guildwood / Morningside / West Hill  Wonder Season Chinese Restaurant
# 2       Guildwood / Morningside / West Hill                  Mahar Restaurant
# 3       Guildwood / Morningside / West Hill          Peking Garden Restaurant
# 4       Guildwood / Morningside / West Hill                        McDonald's
#
#     Restaurant Category
# 0        Breakfast Spot
# 1                   NaN
# 2                   NaN
# 3    Chinese Restaurant
# 4  Fast Food Restaurant

# %%
toronto_restaurants_backup = toronto_restaurants #in case I mess up the dataframe

# %%
#replace NaN values with "Uncategorized" (which I realize I should have just done in the original function)
toronto_restaurants['Restaurant Category'].fillna('Uncategorized', inplace = True)
toronto_restaurants.head()
# Out:
#                                Neighborhood                        Restaurant  \
# 0  Rouge Hill / Port Union / Highland Creek                  Ted's Restaurant
# 1       Guildwood / Morningside / West Hill  Wonder Season Chinese Restaurant
# 2       Guildwood / Morningside / West Hill                  Mahar Restaurant
# 3       Guildwood / Morningside / West Hill          Peking Garden Restaurant
# 4       Guildwood / Morningside / West Hill                        McDonald's
#
#     Restaurant Category
# 0        Breakfast Spot
# 1         Uncategorized
# 2         Uncategorized
# 3    Chinese Restaurant
# 4  Fast Food Restaurant

# %%
#one-hot encoding on restaurant category
toronto_onehot = pd.get_dummies(toronto_restaurants[['Restaurant Category']],prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_restaurants['Neighborhood']
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood
0.00000  0.000000        0.000000      0.0  ...             0.000000
# 11   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 12   0.00000  0.000000        0.020000      0.0  ...             0.040000
# 13   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 14   0.00000  0.021277        0.042553      0.0  ...             0.000000
# 15   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 16   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 17   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 18   0.00000  0.000000        0.071429      0.0  ...             0.000000
# 19   0.00000  0.000000        0.125000      0.0  ...             0.000000
# 20   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 21   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 22   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 23   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 24   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 25   0.00000  0.000000        0.037037      0.0  ...             0.000000
# 26   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 27   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 28   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 29   0.00000  0.000000        0.000000      0.0  ...             0.000000
# ..       ...       ...             ...      ...  ...                  ...
# 56   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 57   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 58   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 59   0.00000  0.000000        1.000000      0.0  ...             0.000000
# 60   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 61   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 62   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 63   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 64   0.02000  0.000000        0.000000      0.0  ...             0.000000
# 65   0.00000  0.000000        0.142857      0.0  ...             0.000000
# 66   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 67   0.02000  0.000000        0.020000      0.0  ...             0.000000
# 68   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 69   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 70   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 71   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 72   0.00000  0.000000        0.058824      0.0  ...             0.000000
# 73   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 74   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 75   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 76   0.00000  0.000000        0.000000      0.0  ...             0.066667
# 77   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 78   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 79   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 80   0.00000  0.000000        0.285714      0.0  ...             0.000000
# 81   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 82   0.00000  0.000000        0.100000      0.0  ...             0.000000
# 83   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 84   0.00000  0.000000        0.000000      0.0  ...             0.000000
# 85   0.00000  0.000000        0.000000      0.0  ...             0.000000
#
#     Thai Restaurant  Theme Restaurant  Tibetan Restaurant  Turkish Restaurant  \
# 0          0.000000              0.00            0.000000            0.000000
# 1          0.000000              0.00            0.000000            0.000000
# 2          0.000000              0.00            0.000000            0.000000
# 3          0.000000              0.00            0.000000            0.000000
# 4          0.023810              0.00            0.000000            0.000000
# 5          0.000000              0.00            0.000000            0.000000
# 6          0.083333              0.00            0.083333            0.000000
# 7          0.000000              0.00            0.000000            0.000000
# 8          0.000000              0.00            0.000000            0.000000
# 9          0.000000              0.00            0.000000            0.000000
# 10         0.000000              0.00            0.000000            0.166667
# 11         0.125000              0.00            0.000000            0.000000
# 12         0.020000              0.02            0.000000            0.000000
# 13         0.000000              0.00            0.000000            0.000000
# 14         0.042553              0.00            0.000000            0.000000
# 15         0.000000              0.00            0.000000            0.000000
# 16         0.000000              0.00            0.000000            0.000000
# 17         0.020000              0.02            0.000000            0.000000
# 18         0.000000              0.00            0.000000            0.000000
# 19         0.062500              0.00            0.000000            0.000000
# 20         0.000000              0.00            0.000000            0.000000
# 21         0.000000              0.00            0.000000            0.000000
# 22         0.000000              0.00            0.000000            0.000000
# 23         0.000000              0.00            0.000000            0.090909
# 24         0.000000              0.00            0.000000            0.000000
# 25         0.037037              0.00            0.000000            0.000000
# 26         0.000000              0.00            0.000000            0.000000
# 27         0.000000              0.00            0.000000            0.000000
# 28         0.020000              0.02            0.000000            0.000000
# 29         0.000000              0.00            0.000000            0.000000
# ..              ...               ...                 ...                 ...
# 56         0.020000              0.02            0.000000            0.000000
# 57         0.000000              0.00            0.000000            0.000000
# 58         0.000000              0.00            0.000000            0.000000
# 59         0.000000              0.00            0.000000            0.000000
# 60         0.000000              0.00            0.000000            0.000000
# 61         0.000000              0.00            0.000000            0.000000
# 62         0.000000              0.00            0.000000            0.000000
# 2                  0.0          0.00000               0.0                 0.0
# 3                  0.0          0.00000               0.0                 0.0
# 4                  0.0          0.02381               0.0                 0.0
#
#    Turkish Restaurant  Uncategorized  Vegetarian / Vegan Restaurant  \
# 0                 0.0       0.083333                            0.0
# 1                 0.0       0.000000                            0.0
# 2                 0.0       0.000000                            0.0
# 3                 0.0       0.166667                            0.0
# 4                 0.0       0.000000                            0.0
#
#    Vietnamese Restaurant  Wine Bar  Wings Joint
# 0                    0.0   0.00000          0.0
# 1                    0.0   0.00000          0.0
# 2                    0.0   0.00000          0.2
# 3                    0.0   0.00000          0.0
# 4                    0.0   0.02381          0.0
#
# [5 rows x 90 columns]

# %%
df1 = toronto_grouped[['Cluster Labels', 'Neighborhood']]
toronto_neighborhoods_clustered = df1.merge(toronto_codes, on = 'Neighborhood', how = 'left').drop_duplicates()
toronto_neighborhoods_clustered
# Out:
#     Cluster Labels                                       Neighborhood  \
# 0                2                                          Agincourt
# 1                3                            Alderwood / Long Branch
# 2                3  Bathurst Manor / Wilson Heights / Downsview North
# 3                3                 Bedford Park / Lawrence Manor East
# 4                3                                        Berczy Park
# 5                3                       Birch Cliff / Cliffside West
# 6                3     Brockton / Parkdale Village / Exhibition Place
# 7                3              Business reply mail Processing CentrE
# 8                3  CN Tower / King and Spadina / Railway Lands / ...
# 9                3                                Caledonia-Fairbanks
# 10               3              Canada Post Gateway Processing Centre
# 11               3                                          Cedarbrae
# 12               2                                 Central Bay Street
# 13               3                                           Christie
# 14               3                               Church and Wellesley
# 15               2          Clarks Corners / Tam O'Shanter / Sullivan
# 16               2  Cliffside / Cliffcrest / Scarborough Village West
# 17               3                    Commerce Court / Victoria Hotel
# 18               3                                         Davisville
# 19               3                                   Davisville North
# 20               2  Del Ray / Mount Dennis / Keelsdale and Silvert...
# 21               3                                          Don Mills
# 22               3                                          Don Mills
# 23               2  Dorset Park / Wexford Heights / Scarborough To...
# 24               2                                          Downsview
# 25               2                                          Downsview
# 26               2                                          Downsview
# 27               2                                          Downsview
# 28               3                      Dufferin / Dovercourt Village
# 29               3                                       East Toronto
# ..             ...                                                ...
# 61               1                                           Rosedale
# 62               3                                           Roselawn
# 63               3           Rouge Hill / Port Union / Highland Creek
# 64               3                                Runnymede / Swansea
# 65               3                     Runnymede / The Junction North
# 66               3                                Scarborough Village
# 67               2  South Steeles / Silverstone / Humbergate / Jam...
# 68               3                                     St. James Town
# 69               3                       St. James Town / Cabbagetown
# 70               2                     Steeles West / L'Amoreaux West
# 71               3                                     Stn A PO Boxes
# 72               3                                    Studio District
# 73               3  Summerhill West / Rathnelly / South Hill / For...
# 74               3              The Annex / North Midtown / Yorkville
# 75               2                                        The Beaches
# 76               3                      The Danforth West / Riverdale
# 77               4    The Kingsway / Montgomery Road / Old Mill North
# 78               3                                   Thorncliffe Park
# 79               3          Toronto Dominion Centre / Design Exchange
# 80               2                    University of Toronto / Harbord
# 81               0                                   Victoria Village
# 82               2                                          Westmount
# 83               3                                             Weston
# 84               3                                 Wexford / Maryvale
# 85               3                                         Willowdale
# 86               3                                         Willowdale
# 87               3                           Willowdale / Newtonbrook
# 88               0                                             Woburn
# 89               3                                   Woodbine Heights


# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_neighborhoods_clustered['Latitude'], toronto_neighborhoods_clustered['Longitude'], toronto_neighborhoods_clustered['Neighborhood'], toronto_neighborhoods_clustered['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(toronto_map_clusters)
       
toronto_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# toronto_grouped.drop('Cluster Labels', axis =1, inplace = True)

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
toronto_restaurants_sorted = pd.DataFrame(columns=columns)
toronto_restaurants_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    toronto_restaurants_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

toronto_restaurants_sorted.head()
# Out:
#                                         Neighborhood  \
# 0                                          Agincourt
# 1                            Alderwood / Long Branch
# 2  Bathurst Manor / Wilson Heights / Downsview North
# 3                 Bedford Park / Lawrence Manor East
# 4                                        Berczy Park
#
#        1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0         Chinese Restaurant        Sandwich Place   American Restaurant
# 1          Korean Restaurant           Pizza Place           Wings Joint
# 2  Middle Eastern Restaurant                   Bar        Sandwich Place
# 3                 Restaurant    Italian Restaurant         Uncategorized
# 4                 Restaurant  Fast Food Restaurant   Japanese Restaurant
#
#   4th Most Common Venue 5th Most Common Venue
# 0     Indian Restaurant         Uncategorized
# 1     German Restaurant    Falafel Restaurant
# 2           Wings Joint     Indian Restaurant
# 3   Filipino Restaurant      Sushi Restaurant
# 4   American Restaurant    Italian Restaurant

# %%
toronto_restaurants_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_restaurants_sorted.head()
# Out:
#    Cluster Labels                                       Neighborhood  \
# 0               2                                          Agincourt
# 1               3                            Alderwood / Long Branch
# 2               3  Bathurst Manor / Wilson Heights / Downsview North
# 3               3                 Bedford Park / Lawrence Manor East
# 4               3                                        Berczy Park
#
#        1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0         Chinese Restaurant        Sandwich Place   American Restaurant
# 1          Korean Restaurant           Pizza Place           Wings Joint
# 2  Middle Eastern Restaurant                   Bar        Sandwich Place
# 3                 Restaurant    Italian Restaurant         Uncategorized
# 4                 Restaurant  Fast Food Restaurant   Japanese Restaurant
#
#   4th Most Common Venue 5th Most Common Venue
# 0     Indian Restaurant         Uncategorized
# 1     German Restaurant    Falafel Restaurant
# 2           Wings Joint     Indian Restaurant
# 3   Filipino Restaurant      Sushi Restaurant
# 4   American Restaurant    Italian Restaurant

# %%
toronto_restaurants_sorted.loc[toronto_restaurants_sorted['Cluster Labels'] == 0]
# Out:
#     Cluster Labels                                       Neighborhood  \
# 26               0  Eringate / Bloordale Gardens / Old Burnhamthor...
# 37               0                                      Humber Summit
# 77               0                                   Victoria Village
# 83               0                                             Woburn
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 26            Restaurant           Wings Joint  Ethiopian Restaurant
# 37            Restaurant           Wings Joint  Ethiopian Restaurant
# 77            Restaurant           Wings Joint  Ethiopian Restaurant
# 83            Restaurant           Wings Joint  Ethiopian Restaurant
#
#    4th Most Common Venue 5th Most Common Venue
# 26    Falafel Restaurant  Fast Food Restaurant
# 37    Falafel Restaurant  Fast Food Restaurant
# 77    Falafel Restaurant  Fast Food Restaurant
# 83    Falafel Restaurant  Fast Food Restaurant

# %%
toronto_restaurants_sorted.loc[toronto_restaurants_sorted['Cluster Labels'] == 1]
# Out:
#     Cluster Labels                    Neighborhood 1st Most Common Venue  \
# 27               1  Fairview / Henry Farm / Oriole   Japanese Restaurant
# 57               1                        Rosedale   Japanese Restaurant
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 27  Middle Eastern Restaurant           Wings Joint     German Restaurant
# 57                Wings Joint     German Restaurant    Falafel Restaurant
#
#    5th Most Common Venue
# 27    Falafel Restaurant
# 57  Fast Food Restaurant

# %%
toronto_restaurants_sorted.loc[toronto_restaurants_sorted['Cluster Labels'] == 2]
# Out:
#     Cluster Labels                                       Neighborhood  \
# 0                2                                          Agincourt
# 12               2                                 Central Bay Street
# 15               2          Clarks Corners / Tam O'Shanter / Sullivan
# 16               2  Cliffside / Cliffcrest / Scarborough Village West
# 20               2  Del Ray / Mount Dennis / Keelsdale and Silvert...
# 22               2  Dorset Park / Wexford Heights / Scarborough To...
# 23               2                                          Downsview
# 36               2                                  Hillcrest Village
# 38               2                                 Humewood-Cedarvale
# 41               2        Kensington Market / Chinatown / Grange Park
# 46               2  Milliken / Agincourt North / Steeles East / L'...
# 63               2  South Steeles / Silverstone / Humbergate / Jam...
# 66               2                     Steeles West / L'Amoreaux West
# 71               2                                        The Beaches
# 76               2                    University of Toronto / Harbord
# 78               2                                          Westmount
#
#    1st Most Common Venue          2nd Most Common Venue  \
# 0     Chinese Restaurant                 Sandwich Place
# 12    Chinese Restaurant                     Restaurant
# 15    Chinese Restaurant           Caribbean Restaurant
# 16    Chinese Restaurant                    Wings Joint
# 20    Chinese Restaurant                    Wings Joint
# 22    Chinese Restaurant              Indian Restaurant
# 23    Chinese Restaurant      Latin American Restaurant
# 36   Japanese Restaurant                 Sandwich Place
# 38        Breakfast Spot      Middle Eastern Restaurant
# 41    Chinese Restaurant          Vietnamese Restaurant
# 46    Chinese Restaurant  Vegetarian / Vegan Restaurant
# 63            Restaurant             Chinese Restaurant
# 66    Chinese Restaurant              Indian Restaurant
# 71   Japanese Restaurant             Chinese Restaurant
# 76    Chinese Restaurant                     Restaurant
# 78            Restaurant             Chinese Restaurant
#
#         3rd Most Common Venue  4th Most Common Venue  5th Most Common Venue
# 0         American Restaurant      Indian Restaurant          Uncategorized
# 12          Indian Restaurant     Dim Sum Restaurant                  Diner
# 15                Wings Joint      German Restaurant   Fast Food Restaurant
# 16                Event Space   Fast Food Restaurant    Filipino Restaurant
# 20                Event Space   Fast Food Restaurant    Filipino Restaurant
# 22  Middle Eastern Restaurant            Wings Joint      German Restaurant
# 23                 Restaurant    Filipino Restaurant     Turkish Restaurant
# 36         Chinese Restaurant            Wings Joint  General Entertainment
# 38         Chinese Restaurant            Wings Joint      German Restaurant
# 41         Dim Sum Restaurant      Korean Restaurant       Asian Restaurant
# 46     Furniture / Home Store            Wings Joint      German Restaurant
# 63                Wings Joint  General Entertainment     Falafel Restaurant
# 66                Wings Joint      German Restaurant   Fast Food Restaurant
# 71       Caribbean Restaurant       Asian Restaurant     Italian Restaurant
# 76             Sandwich Place    Szechuan Restaurant   Caribbean Restaurant
# 78                Wings Joint  General Entertainment     Falafel Restaurant

# %%
toronto_restaurants_sorted.loc[toronto_restaurants_sorted['Cluster Labels'] == 3]
# Out:
#     Cluster Labels                                       Neighborhood  \
# 1                3                            Alderwood / Long Branch
# 2                3  Bathurst Manor / Wilson Heights / Downsview North
# 3                3                 Bedford Park / Lawrence Manor East
# 4                3                                        Berczy Park
# 5                3                       Birch Cliff / Cliffside West
# 6                3     Brockton / Parkdale Village / Exhibition Place
# 7                3              Business reply mail Processing CentrE
# 53           Greek Restaurant       Fast Food Restaurant
# 54          Indian Restaurant                 Restaurant
# 55            Thai Restaurant                       Food
# 56          Indian Restaurant        American Restaurant
# 58          German Restaurant         Falafel Restaurant
# 59           Greek Restaurant       Fast Food Restaurant
# 60        American Restaurant                      Diner
# 61       Caribbean Restaurant                Wings Joint
# 62       Caribbean Restaurant                Wings Joint
# 64          Indian Restaurant        American Restaurant
# 65          Indian Restaurant             Breakfast Spot
# 67        Japanese Restaurant       Fast Food Restaurant
# 68        American Restaurant              Uncategorized
# 69                 Restaurant       Cantonese Restaurant
# 70   Mediterranean Restaurant  Middle Eastern Restaurant
# 72           Sushi Restaurant             Sandwich Place
# 74         Chinese Restaurant       Caribbean Restaurant
# 75        Japanese Restaurant           Asian Restaurant
# 79                      Diner            Thai Restaurant
# 80          Korean Restaurant          Indian Restaurant
# 81          Korean Restaurant                 Restaurant
# 82           Asian Restaurant          Indian Restaurant
# 84          German Restaurant         Falafel Restaurant
#
#         5th Most Common Venue
# 1          Falafel Restaurant
# 2           Indian Restaurant
# 3            Sushi Restaurant
# 4          Italian Restaurant
# 5          Falafel Restaurant
# 6                       Diner
# 7        Fast Food Restaurant
# 8         Filipino Restaurant
# 9   Middle Eastern Restaurant
# 10         Chinese Restaurant
# 11            Thai Restaurant
# 13         African Restaurant
# 14           Sushi Restaurant
# 17    New American Restaurant
# 18      General Entertainment
# 19                     Office
# 21      General Entertainment
# 24       Ethiopian Restaurant
# 25         Chinese Restaurant
# 28       Caribbean Restaurant
# 29                 Steakhouse
# 30           Asian Restaurant
# 31                Wings Joint
# 32         Falafel Restaurant
# 33          German Restaurant
# 34                        Bar
# 35      General Entertainment
# 39                Wings Joint
# 40          German Restaurant
# 42       Fast Food Restaurant
# ..                        ...
# 45    New American Restaurant
# 47         Falafel Restaurant
# 48              Uncategorized
# 49       Fast Food Restaurant
# 50            Thai Restaurant
# 51                       Café
# 52                        Bar
# 53        Filipino Restaurant
# 54           Sushi Restaurant
# 55                      Diner
# 56         Chinese Restaurant
# 58       Fast Food Restaurant
# 59        Filipino Restaurant
# 60          French Restaurant
# 61      General Entertainment
# 62          German Restaurant
# 64           Sushi Restaurant
# 65                Karaoke Bar
# 67          Indian Restaurant
# 68           Asian Restaurant
# 69                 Steakhouse
# 70                 Restaurant
# 72       Caribbean Restaurant
# 74         Miscellaneous Shop
# 75                        Bar
# 79       Caribbean Restaurant
# 80           Halal Restaurant
# 81           Hunan Restaurant
# 82             Breakfast Spot
# 84       Fast Food Restaurant
#
# [61 rows x 7 columns]

# %%
toronto_restaurants_sorted.loc[toronto_restaurants_sorted['Cluster Labels'] == 4]
# Out:
#     Cluster Labels                                     Neighborhood  \
# 44               4                                          Leaside
# 73               4  The Kingsway / Montgomery Road / Old Mill North
# 85               4                                  York Mills West
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 44     Indian Restaurant      Sushi Restaurant           Wings Joint
# 73      Sushi Restaurant           Wings Joint     German Restaurant
# 85                 Diner      Sushi Restaurant           Wings Joint
#
#    4th Most Common Venue 5th Most Common Venue
# 44     German Restaurant    Falafel Restaurant
# 73    Falafel Restaurant  Fast Food Restaurant
# 85     German Restaurant    Falafel Restaurant
